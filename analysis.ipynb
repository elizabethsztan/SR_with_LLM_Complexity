# %% [markdown]
# analysis of the findings

# %%
import json 

complex_no = 1764946995
simple_no = 1764945805

with open(f"experimental_results/simple_expression/llm_complexity_log_{simple_no}.json", "r") as f:
    llm_complexities = json.load(f)

with open(f"experimental_results/simple_expression/standard_complexity_log_{simple_no}.json", "r") as f:
    standard_complexities = json.load(f)

# %% [markdown]
# These should be more or less the same

# %%
len(llm_complexities)
# Out:
# 15193

# %%
len(standard_complexities)
# Out:
# 15335

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(llm_complexities, bins = 30)
plt.xlabel('Complexity')
plt.ylabel('Frequency')
plt.title('Qwen complexities: simple expression')
# Out:
# Text(0.5, 1.0, 'Qwen complexities: simple expression')

# %%
plt.hist(standard_complexities, bins = 30)
plt.xlabel('Complexity')
plt.ylabel('Frequency')
plt.title('Standard complexities: simple expression')
# Out:
# Text(0.5, 1.0, 'Standard complexities: simple expression')

# %%
with open(f"experimental_results/complex_expression/llm_complexity_log_{complex_no}.json", "r") as f:
    llm_complexities_complex = json.load(f)

with open(f"experimental_results/complex_expression/standard_complexity_log_{complex_no}.json", "r") as f:
    standard_complexities_complex = json.load(f)

# %%
plt.hist(llm_complexities_complex, bins = 30)
plt.xlabel('Complexity')
plt.ylabel('Frequency')
plt.title('Qwen complexities: complex expression')
# Out:
# Text(0.5, 1.0, 'Qwen complexities: complex expression')

# %%
plt.hist(standard_complexities_complex, bins = 30)
plt.xlabel('Complexity')
plt.ylabel('Frequency')
plt.title('Standard complexities: complex expression')
# Out:
# Text(0.5, 1.0, 'Standard complexities: complex expression')
